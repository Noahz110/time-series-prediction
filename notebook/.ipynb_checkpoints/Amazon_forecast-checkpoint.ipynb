# %%
import warnings
import random
from mpl_toolkits.mplot3d import Axes3D
import itertools
import pandas as pd
from sklearn.metrics import mean_squared_error
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
# %matplotlib inline

# %%
data = pd.read_csv('/home/dangdbh/Downloads/time-series-prediction-testcases/demo_aws_forecast/input_AWS_predict/request.csv', engine='python', names=['timestamp', 'metric_value'], skiprows=1)
data['timestamp']=pd.to_datetime(data['timestamp'], format='%Y-%m-%d %H:%M:%S')
data.set_index(['timestamp'], inplace=True)

# %%
data2 = pd.read_csv('/home/dangdbh/Downloads/time-series-prediction-testcases/demo_aws_forecast/input_AWS_predict/data_transfer.csv', engine='python', names=['timestamp', 'metric_value'], skiprows=1)
data2['timestamp']=pd.to_datetime(data2['timestamp'], format='%Y-%m-%d %H:%M:%S')
data2.set_index(['timestamp'], inplace=True)

# %%
predict_len =275

# %%
data.head()
# data['s3.request'] = data['metric_value']
# Out:
#                      metric_value
# timestamp
# 2019-11-30 17:00:00        6150.0
# 2019-11-30 18:00:00        3800.0
# 2019-11-30 19:00:00        2960.0
# 2019-11-30 20:00:00        2190.0
# 2019-11-30 21:00:00        1160.0

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)
# # plt.rcParams.update({'font.size': 12})
# # plt.style.use('ggplot')
data.plot()
plt.ylabel('Hourly datatransfer')
plt.xlabel('Date')
plt.legend(loc=2)
plt.show()

# %%
train_data = data['2019-11-30 17:00:00':'2019-12-19 22:00:00']
test_data = data['2019-12-19 23:00:00':'2019-12-26 09:00:00']
train_len = len(train_data)
test_len = len(test_data)

# %%
### ARIMA model

# %%
p = q = d = range(0, 3)
pdq = list(itertools.product(p, d, q))

# %%
seasonal_pdq = [(x[0], x[1], x[2], 1) for x in list(itertools.product(p, d, q))]

# %%
train_data.head()
# Out:
#                      metric_value
# timestamp
# 2019-11-30 17:00:00        6150.0
# 2019-11-30 18:00:00        3800.0
# 2019-11-30 19:00:00        2960.0
# 2019-11-30 20:00:00        2190.0
# 2019-11-30 21:00:00        1160.0

# %%
warnings.filterwarnings("ignore")

# %%
AIC = []
ARIMA_model = []
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = SARIMAX(train_data,
                          order=param,
                          seasonal_order=param_seasonal,
                          enforce_stationarity=False,
                          enforce_invertibility=False)

            results = mod.fit()

            print('SARIMAX{}x{} - AIC:{}'.format(param, param_seasonal, results.aic), end='\r')
            AIC.append(results.aic)
            ARIMA_model.append([param, param_seasonal])
        except Exception as e:
            print(e)
            continue
# Out:
# SARIMAX(2, 2, 2)x(2, 2, 2, 1) - AIC:8505.054951776827

# %%
print('The smallest AIC is {} for model SARIMAX{}x{}'.format(min(AIC), ARIMA_model[AIC.index(min(AIC))][0],ARIMA_model[AIC.index(min(AIC))][1]))
# Out:
# The smallest AIC is 8226.332550947078 for model SARIMAX(2, 0, 2)x(1, 1, 2, 1)

# %%
mod = SARIMAX(train_data,
              order=ARIMA_model[AIC.index(min(AIC))][0],
              seasonal_order=ARIMA_model[AIC.index(min(AIC))][1],
              enforce_stationarity=False,
              enforce_invertibility=False)
arima_fit = mod.fit()

# %%
# best param

# %%
mod = SARIMAX(train_data,
              order=(0,0,0),
              seasonal_order=(2,2,2,24),
              enforce_stationarity=False,
              enforce_invertibility=False)
arima_fit = mod.fit()
# Out:
# /home/dangdbh/.local/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency H will be used.
#   % freq, ValueWarning)

# %%
pred2 = arima_fit.get_forecast('2019-12-31 09:00:00')
pred2_ci = pred2.conf_int()

# %%
pred3 = arima_fit.predict(start='2019-12-19 23:00:00', end='2019-12-31 09:00:00')

# %%
pred2.prediction_results

# %%
arima_fit.get_forecast()

# %%
pred2_ci.head()
# Out:
#                      lower metric_value  upper metric_value
# 2019-12-19 23:00:00        -1641.006076         5472.547284
# 2019-12-20 00:00:00         -681.243734         6432.309626
# 2019-12-20 01:00:00         1089.266954         8202.820314
# 2019-12-20 02:00:00          277.761171         7391.314531
# 2019-12-20 03:00:00         1661.112510         8774.665870

# %%
pred2.predicted_mean['2019-12-26 10:00:00':'2019-12-31 09:00:00']
# Out:
# 2019-12-26 10:00:00     4190.731586
# 2019-12-26 11:00:00     8171.900964
# 2019-12-26 12:00:00     8343.307592
# 2019-12-26 13:00:00     6171.938539
# 2019-12-26 14:00:00     6328.163461
# 2019-12-26 15:00:00    10446.943251
# 2019-12-26 16:00:00    10518.821950
# 2019-12-26 17:00:00     7546.166186
# 2019-12-26 18:00:00     4271.288666
# 2019-12-26 19:00:00     6294.385207
# 2019-12-26 20:00:00     4482.878872
# 2019-12-26 21:00:00     1737.042806
# 2019-12-26 22:00:00      965.319341
# 2019-12-26 23:00:00     2385.189396
# 2019-12-27 00:00:00     3246.535182
# 2019-12-27 01:00:00     5705.096113
# 2019-12-27 02:00:00     4128.327288
# 2019-12-27 03:00:00     5134.788659
# 2019-12-27 04:00:00     5244.392558
# 2019-12-27 05:00:00     9127.981482
# 2019-12-27 06:00:00     6390.178652
# 2019-12-27 07:00:00     5411.729058
# 2019-12-27 08:00:00     7674.640227
# 2019-12-27 09:00:00     5759.747503
# 2019-12-27 10:00:00     4210.256185
# 2019-12-27 11:00:00     8407.682879
# 2019-12-27 12:00:00     8591.053513
# 2019-12-27 13:00:00     6246.777373
# 2019-12-27 14:00:00     6337.223900
# 2019-12-27 15:00:00    10640.020433
#                            ...
# 2019-12-30 04:00:00     5348.085368
# 2019-12-30 05:00:00     9824.797386
# 2019-12-30 06:00:00     6457.103911
# 2019-12-30 07:00:00     5258.207493
# 2019-12-30 08:00:00     8081.289411
# 2019-12-30 09:00:00     5856.865822
# 2019-12-30 10:00:00     4269.528688
# 2019-12-30 11:00:00     9124.018196
# 2019-12-30 12:00:00     9341.095015
# 2019-12-30 13:00:00     6470.037615
# 2019-12-30 14:00:00     6365.770522
# 2019-12-30 15:00:00    11224.751557
# 2019-12-30 16:00:00    11130.557458
# 2019-12-30 17:00:00     7604.127699
# 2019-12-30 18:00:00     4062.960163
# 2019-12-30 19:00:00     7446.677771
# 2019-12-30 20:00:00     5176.112291
# 2019-12-30 21:00:00     1807.776894
# 2019-12-30 22:00:00      869.653251
# 2019-12-30 23:00:00     2695.765253
# 2019-12-31 00:00:00     3476.091785
# 2019-12-31 01:00:00     6366.510117
# 2019-12-31 02:00:00     4137.226936
# 2019-12-31 03:00:00     5053.620388
# 2019-12-31 04:00:00     5382.778852
# 2019-12-31 05:00:00    10057.266393
# 2019-12-31 06:00:00     6479.549319
# 2019-12-31 07:00:00     5206.734386
# 2019-12-31 08:00:00     8217.295559
# 2019-12-31 09:00:00     5889.154029
# Freq: H, Length: 120, dtype: float64

# %%
ax = data.plot(figsize=(20, 10))
pred2.predicted_mean.plot(ax=ax, label='forecast')
ax.fill_between(pred2_ci.index, pred2_ci.iloc[:, 0], pred2_ci.iloc[:, 1], color='k', alpha=.1)
plt.ylabel('s3.data_transfer')
plt.xlabel('Date')
plt.legend(loc=2)
plt.show()

# %%
# Root Mean Square Error (RMSE)
rmse_ARIMA = np.sqrt(mean_squared_error(test_data['metric_value'], pred2.predicted_mean['2019-12-19 23:00:00':'2019-12-26 09:00:00']))
rmse_ARIMA = round(rmse_ARIMA, 3)
rmse_ARIMA
# Out:
# 2370.96

# %%
# Mean Absolute Percentage Error
abs_error = np.abs(test_data['metric_value']-pred2.predicted_mean['2019-12-19 23:00:00':'2019-12-26 09:00:00'])
actual = test_data['metric_value']
mape_ARIMA = np.round(np.mean(np.abs(abs_error/actual)),3)
mape_ARIMA
# Out:
# 0.402

# %%
# Exponetial smoothing

# %%
pred = test_data.copy()

# %%
ets_fit = ExponentialSmoothing(train_data['metric_value'],seasonal_periods=24 ,trend='add', seasonal='add', freq='H', damped=True).fit(damping_slope=0.2)
ets_fit.params
# Out:
# {'damping_slope': 0.2,
#  'initial_level': 7042.500000000113,
#  'initial_seasons': array([ -892.5, -3242.5, -4082.5, -4852.5, -5882.5, -6242.5, -6632.5,
#         -5152.5, -3772.5, -3202.5, -2932.5,  -192.5, -3032.5,   637.5,
#         -3222.5, -2652.5, -2182.5, -2352.5, -4202.5, -3512.5, -2872.5,
#         -1592.5, -2362.5,  -142.5]),
#  'initial_slope': 16.92708333336486,
#  'lamda': None,
#  'remove_bias': False,
#  'smoothing_level': 0.052631578947366676,
#  'smoothing_seasonal': 0.1578947368421331,
#  'smoothing_slope': 0.05263157894736842,
#  'use_boxcox': False}

# %%
Forecasting = ets_fit.forecast(predict_len)

# %%
idx = pd.date_range(start='2019-12-19 23:00:00', periods=predict_len, freq='H')
Forecasting = pd.Series(Forecasting,index=idx)

# %%
Forecasting
# Out:
# 2019-12-19 23:00:00    2615.657128
# 2019-12-20 00:00:00    3595.341742
# 2019-12-20 01:00:00    4759.958495
# 2019-12-20 02:00:00    4875.003290
# 2019-12-20 03:00:00    6362.376563
# 2019-12-20 04:00:00    5942.701223
# 2019-12-20 05:00:00    7364.961518
# 2019-12-20 06:00:00    7125.237484
# 2019-12-20 07:00:00    6825.213493
# 2019-12-20 08:00:00    6977.821794
# 2019-12-20 09:00:00    6382.987385
# 2019-12-20 10:00:00    5069.463000
# 2019-12-20 11:00:00    6556.333138
# 2019-12-20 12:00:00    6662.307115
# 2019-12-20 13:00:00    6247.369028
# 2019-12-20 14:00:00    7027.284177
# 2019-12-20 15:00:00    8971.609967
# 2019-12-20 16:00:00    9537.273046
# 2019-12-20 17:00:00    8270.411046
# 2019-12-20 18:00:00    5644.351401
# 2019-12-20 19:00:00    4432.129510
# 2019-12-20 20:00:00    3622.341850
# 2019-12-20 21:00:00    2310.070342
# 2019-12-20 22:00:00    2285.159429
# 2019-12-20 23:00:00    2615.409322
# 2019-12-21 00:00:00    3595.292180
# 2019-12-21 01:00:00    4759.948582
# 2019-12-21 02:00:00    4875.001308
# 2019-12-21 03:00:00    6362.376166
# 2019-12-21 04:00:00    5942.701143
#                           ...
# 2019-12-30 04:00:00    5942.701143
# 2019-12-30 05:00:00    7364.961502
# 2019-12-30 06:00:00    7125.237480
# 2019-12-30 07:00:00    6825.213492
# 2019-12-30 08:00:00    6977.821794
# 2019-12-30 09:00:00    6382.987385
# 2019-12-30 10:00:00    5069.463000
# 2019-12-30 11:00:00    6556.333138
# 2019-12-30 12:00:00    6662.307115
# 2019-12-30 13:00:00    6247.369028
# 2019-12-30 14:00:00    7027.284177
# 2019-12-30 15:00:00    8971.609967
# 2019-12-30 16:00:00    9537.273046
# 2019-12-30 17:00:00    8270.411046
# 2019-12-30 18:00:00    5644.351401
# 2019-12-30 19:00:00    4432.129510
# 2019-12-30 20:00:00    3622.341850
# 2019-12-30 21:00:00    2310.070342
# 2019-12-30 22:00:00    2285.159429
# 2019-12-30 23:00:00    2615.409322
# 2019-12-31 00:00:00    3595.292180
# 2019-12-31 01:00:00    4759.948582
# 2019-12-31 02:00:00    4875.001308
# 2019-12-31 03:00:00    6362.376166
# 2019-12-31 04:00:00    5942.701143
# 2019-12-31 05:00:00    7364.961502
# 2019-12-31 06:00:00    7125.237480
# 2019-12-31 07:00:00    6825.213492
# 2019-12-31 08:00:00    6977.821794
# 2019-12-31 09:00:00    6382.987385
# Freq: H, Length: 275, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.plot(train_data['metric_value'], label='Train')
plt.plot(test_data['metric_value'], label='Test')
plt.plot(Forecasting, label='SETS')
plt.legend(loc='best')
plt.show()

# %%
# Root Mean Square Error (RMSE)
rmse_ETS = np.sqrt(mean_squared_error(test_data.metric_value, Forecasting['2019-12-19 23:00:00':'2019-12-26 09:00:00']))
rmse_ETS = round(rmse_ETS, 3)
rmse_ETS
# Out:
# 2032.634

# %%
# Mean Absolute Percentage Error
abs_error = np.abs(test_data['metric_value']-Forecasting['2019-12-19 23:00:00':'2019-12-26 09:00:00'])
actual = test_data['metric_value']
mape_ETS = np.round(np.mean(abs_error/actual),4)
mape_ETS
# Out:
# 0.4074

# %%
# Multiplicative

# %%
y_hat_avg = test_data.copy()

# %%
mod = ExponentialSmoothing(train_data['metric_value'] ,seasonal_periods=24 ,trend='add', seasonal='mul', freq='H', damped=True)
fit1 = mod.fit(damping_slope=0.3)
fit1.params
# Out:
# /home/dangdbh/.local/lib/python3.6/site-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# {'damping_slope': 0.3,
#  'initial_level': 7042.5,
#  'initial_seasons': array([0.87326944, 0.53958111, 0.42030529, 0.31096912, 0.16471424,
#         0.11359602, 0.05821796, 0.26837061, 0.46432375, 0.54526092,
#         0.58359957, 0.97266596, 0.56940007, 1.09052183, 0.54242102,
#         0.62335818, 0.69009585, 0.66595669, 0.40326589, 0.50124246,
#         0.59211928, 0.77387291, 0.66453674, 0.97976571]),
#  'initial_slope': 16.927083333333332,
#  'lamda': None,
#  'remove_bias': False,
#  'smoothing_level': 0.05263157894736842,
#  'smoothing_seasonal': 0.15789473684210525,
#  'smoothing_slope': 0.05263157894736842,
#  'use_boxcox': False}

# %%
Forecasting.head()
# Out:
# 2019-12-19 23:00:00    2615.657128
# 2019-12-20 00:00:00    3595.341742
# 2019-12-20 01:00:00    4759.958495
# 2019-12-20 02:00:00    4875.003290
# 2019-12-20 03:00:00    6362.376563
# Freq: H, dtype: float64

# %%
Forecasting = fit1.forecast(predict_len)
idx = pd.date_range(start='2019-12-19 23:00:00', periods=predict_len, freq='H')
Forecasting = pd.Series(Forecasting,index=idx)

# %%
plt.figure(figsize=(20,10))
plt.plot(train_data['metric_value'], label='Train')
plt.plot(test_data['metric_value'], label='Test')
plt.plot(Forecasting, label='METS')
plt.legend(loc='best')
plt.show()

# %%
# Root Mean Square Error (RMSE)
rmse_ETS = np.sqrt(mean_squared_error(test_data.metric_value, Forecasting['2019-12-19 23:00:00':'2019-12-26 09:00:00']))
rmse_ETS = round(rmse_ETS, 3)
rmse_ETS
# Out:
# 2042.375

# %%
# Mean Absolute Percentage Error
abs_error = np.abs(test_data['metric_value']-Forecasting['2019-12-19 23:00:00':'2019-12-26 09:00:00'])
actual = test_data['metric_value']
mape_ETS = np.round(np.mean(abs_error/actual),4)
mape_ETS
# Out:
# 0.3634

# %%
# NPTS

# %%
from gluonts.model.npts import NPTSEstimator, NPTSPredictor
from gluonts.trainer import Trainer

# %%
from gluonts.dataset.common import ListDataset
training_data = ListDataset(
    [{"start": data.index[0], "target": data.metric_value[:"2019-12-19 22:00:00"]}],
    freq = "H"
)

# %%
estimator = NPTSEstimator(freq="H", prediction_length=predict_len)
# predictor = estimator.train(training_data=training_data)
predictor = NPTSPredictor(context_length=train_len, freq="H", prediction_length=predict_len)

# %%
idx = pd.date_range(start='2019-12-19 23:00:00', periods=predict_len, freq='H')
Forecasting = pd.Series(Forecasting,index=idx)

# %%
from gluonts.dataset.util import to_pandas

for test_entry, forecast in zip(training_data, predictor.predict(training_data)):
#     to_pandas(test_entry)[:].plot(linewidth=2)
#     idx = pd.date_range(start='2019-12-19 23:00:00', periods=predict_len, freq='H')
#     Forecasting = pd.Series(forecast.median,index=idx)
    ax = train_data.plot()
    test_data.plot(ax=ax)
    forecast.plot(color='g', prediction_intervals=[0.0])
    NPTS_forecast = forecast
#     Forecasting.plot(color='r', ls='--')
plt.grid(which='both')

# %%
NPTS_forecast.median
# Out:
# array([1290., 2520., 2980., 3770., 5420., 4550., 5810., 6520., 5570.,
#        5660., 5190., 4100., 4360., 4380., 5070., 5440., 7330., 8410.,
#        7060., 4280., 2040., 1620., 1160.,  800., 1240., 2470., 3210.,
#        3770., 5420., 4550., 5810., 6510., 6900., 5640., 5250., 4100.,
#        4880., 4570., 5070., 7020., 7330., 7940., 6960., 4810., 2070.,
#        1550., 1430.,  880., 1290., 2470., 2870., 3340., 5600., 4150.,
#        5810., 6520., 5130., 5640., 5250., 4100., 5170., 5060., 5070.,
#         430., 1320., 1730., 2020., 3120., 3250., 3090., 3850., 3820.,
#        4030., 4160., 2410., 3140., 3210., 3360., 4340., 5350., 6000.,
#        4780., 2930., 1300.,  860.,  830.,  240.,  430., 1340., 1580.,
#        2020., 3120., 3040., 3090., 4200., 3820., 4030., 4100., 2410.,
#        3140., 3330., 3360., 3780., 5350., 6670., 4670., 2930., 1300.,
#         840.,  520.,  190.,  410., 1340., 1580., 2050., 3120., 3250.,
#        3090., 3150., 3820., 4030., 4100., 2750., 3140., 3330., 3360.,
#        4340., 5350., 6670., 4940., 2870.,  890.,  860.,  830.,  240.,
#         430., 1340., 1580., 2050., 3120., 3250., 4010., 4200., 4000.,
#        4120., 4100., 2410., 2840., 3210., 3490., 4340., 5350., 6670.,
#        4670., 2870., 1300.,  450.,  520.,  240.,  500., 1550., 1580.,
#        2050., 3440., 3250., 3090., 3850., 4000., 4030., 2890., 2410.,
#        2840., 3330., 3360., 3780., 5350., 6000., 4780., 2870., 1300.,
#         840.,  830.,  240.,  430., 1550., 1580., 2050., 3310., 3250.,
#        3090., 3850., 4000., 4030., 4100.])

# %%
# Root Mean Square Error (RMSE)
rmse_NPTS = np.sqrt(mean_squared_error(test_data.metric_value, NPTS_forecast.median[:test_len]))
rmse_NPTS = round(rmse_NPTS, 3)
rmse_NPTS
# Out:
# 2140.109

# %%
# Mean Absolute Percentage Error
abs_error = np.abs(test_data['metric_value'] - NPTS_forecast.median[:test_len])
actual = test_data['metric_value']
mape_NPTS = np.round(np.mean(abs_error/actual),4)
mape_NPTS
# Out:
# 0.2719

# %%
#Prophet

# %%
from fbprophet import Prophet

# %%
data = pd.read_csv('/home/dangdbh/Downloads/time-series-prediction-testcases/demo_aws_forecast/input_AWS_predict/request.csv', engine='python', names=['metric_name','timestamp', 'metric_value'], skiprows=1)

# %%
df = data[:train_len]
# df = data

# %%
df['ds'] = df['timestamp']
df['y'] = df['metric_value']

# %%
df = df.drop(labels=['metric_name','timestamp', 'metric_value'], axis=1)

# %%
m = Prophet(seasonality_mode=random.choice(['additive','multiplicative']),yearly_seasonality=False)
# m = Prophet()
# m.add_country_holidays(country_name='VN')
m.fit(df)
future = m.make_future_dataframe(predict_len, freq='H')
forecast = m.predict(future)
fig = m.plot(forecast)

# %%
plt.rcParams['figure.figsize'] = (20.0, 10.0)
# # plt.rcParams.update({'font.size': 12})
# # plt.style.use('ggplot')
# data['timestamp']=pd.to_datetime(data['timestamp'], format='%Y-%m-%d %H:%M:%S')
data.set_index(['timestamp'], inplace=True)
ax = data.metric_value.plot()
forecast[-predict_len:].yhat.plot(ax=ax, label='Prophet Forecast')
plt.ylabel('Hourly request')
plt.xlabel('Date')
plt.legend(loc=2)
plt.show()

# %%
forecast
# Out:
#                      ds        trend  trend_lower  trend_upper   yhat_lower  \
# 0   2019-11-30 17:00:00  4268.626218  4268.626218  4268.626218  4155.327851
# 1   2019-11-30 18:00:00  4269.715833  4269.715833  4269.715833  2449.465658
# 2   2019-11-30 19:00:00  4270.805448  4270.805448  4270.805448   610.694719
# 3   2019-11-30 20:00:00  4271.895062  4271.895062  4271.895062  -721.735828
# 725     -0.041596     -0.041596  1129.173501
# 726     -0.044199     -0.044199  1692.568643
# 727     -0.046438     -0.046438  2489.559168
# 728     -0.048295     -0.048295  3425.303823
# 729     -0.049759     -0.049759  4450.856858
# 730     -0.050821     -0.050821  5437.941473
# 731     -0.051482     -0.051482  6203.275065
# 732     -0.051743     -0.051743  6637.659070
# 733     -0.051615     -0.051615  6773.152048
# 734     -0.051111     -0.051111  6704.136408
# 735     -0.050249     -0.050249  6462.544626
# 736     -0.049052     -0.049052  6017.209397
#
# [737 rows x 19 columns]

# %%
forecast.quantile()
# Out:
# trend                         4734.523119
# trend_lower                   4734.523119
# trend_upper                   4734.523119
# yhat_lower                    3219.248475
# yhat_upper                    7017.934145
# additive_terms                   0.000000
# additive_terms_lower             0.000000
# additive_terms_upper             0.000000
# daily                            0.047312
# daily_lower                      0.047312
# daily_upper                      0.047312
# multiplicative_terms             0.082129
# multiplicative_terms_lower       0.082129
# multiplicative_terms_upper       0.082129
# weekly                          -0.002018
# weekly_lower                    -0.002018
# weekly_upper                    -0.002018
# yhat                          5122.508103
# Name: 0.5, dtype: float64

# %%
fig = m.plot_components(forecast)

# %%
#prophet AWS

# %%
from gluonts.model.prophet import ProphetPredictor
from fbprophet import Prophet

# %%
from gluonts.dataset.common import ListDataset
training_data = ListDataset(
    [{"start": data.index[0], "target": data.metric_value[:"2019-12-19 22:00:00"]}],
    freq = "H"
)

# %%
# estimator = NPTSEstimator(freq="H", prediction_length=predict_len)
# predictor = estimator.train(training_data=training_data)
m = Prophet(seasonality_mode=random.choice(['additive','multiplicative']),yearly_seasonality=False)
prophet_params = {'seasonality_mode': 'multiplicative', 'yearly_seasonality': False}
predictor = ProphetPredictor(prophet_params=prophet_params, freq="H", prediction_length=predict_len)

# %%
from gluonts.dataset.util import to_pandas
plt.rcParams['figure.figsize'] = (20.0, 10.0)

for test_entry, forecast in zip(training_data, predictor.predict(training_data)):
#     to_pandas(test_entry)[:].plot(linewidth=2)
#     idx = pd.date_range(start='2019-12-19 23:00:00', periods=predict_len, freq='H')
#     Forecasting = pd.Series(forecast.median,index=idx)
    ax = train_data.plot()
    test_data.plot(ax=ax)
    forecast.plot(color='g', prediction_intervals=[0.0, 99])
    Prophet_forecast = forecast
#     Forecasting.plot(color='r', ls='--')
plt.grid(which='both')

# %%
# Root Mean Square Error (RMSE)
rmse_Prophet = np.sqrt(mean_squared_error(test_data.metric_value, Prophet_forecast.median[:test_len]))
rmse_Prophet = round(rmse_Prophet, 3)
rmse_Prophet
# Out:
# 1970.707

# %%
# Mean Absolute Percentage Error
abs_error = np.abs(test_data['metric_value'] - Prophet_forecast.median[:test_len])
actual = test_data['metric_value']
mape_Prophet = np.round(np.mean(abs_error/actual),4)
mape_Prophet
# Out:
# 0.2823

# %%
from gluonts.model.forecast import Quantile

# %%
num_samples = 100

# %%
samples = Prophet_forecast.samples

# %%
test = np.sort(samples, axis=0)

# %%
Prophet_forecast.quantile(0.5)
# Out:
# array([2116.214453  , 2824.24122447, 3868.58745807, 4645.51042061,
#        4063.59699831, 2473.61650815, 1695.2472604 , 1176.3296624 ,
#        1946.6235309 , 2346.76952138, 3473.41004007, 4885.92543049,
#        5488.94347689, 6422.66392941, 6665.118594  , 6436.16776744,
#        6717.65389445, 6216.20100763, 5837.26894975, 5295.52307616,
#        4811.82878188, 5025.56381493, 5640.32699478, 7064.50938635,
#        8432.70933504, 8748.64247201, 7647.8819056 , 5175.35118043,
#        3406.12355137, 1753.06099287,  691.558788  ,  889.55583449,
#        1642.97202404, 2189.83131379, 3168.53796068, 4080.48969403,
#        5293.96061062, 5998.45241924, 6592.22188453, 6866.14424524,
#        6915.11365393, 6408.38814319, 6238.20822187, 5657.76715222,
#        5313.05431839, 5356.98441565, 6289.65323793, 7563.85823929,
#        9142.7024631 , 9632.93464452, 8362.51477653, 6045.98705085,
#        3802.06024791, 1731.15366503, 1396.23851558, 1422.01102515,
#        2154.12577106, 2613.28019175, 3537.78995945, 4741.09561102,
#        5791.16903742, 6553.20350617, 7041.02134344, 7160.21240012,
#        6789.62997959, 6483.83753524, 6337.91481302, 5749.58385997,
#        5295.19504057, 5590.88286352, 6609.0117205 , 7792.30412437,
#        9107.17357428, 9367.89300746, 8105.15823665, 5752.13435762,
#        3753.68523031, 1620.69179848, 1203.34535684, 1242.22681022,
#        1534.7838565 , 2379.57326062, 3481.50773883, 4474.41891467,
#        5410.84042536, 6412.00496955, 6544.4116726 , 6772.37362731,
#        6851.8847799 , 6400.15085051, 6380.6484775 ])

# %%
q = Quantile.parse(0.9).value
q
# Out:
# 0.9

# %%
sample_idx = int(np.round((100 - 1) * q))
sample_idx
# Out:
# 89

# %%
q90 = test[sample_idx, :]

# %%
test
# Out:
# array([[-1625.73326672,  -595.96790403,  -383.03439278, ...,
#          2806.42028166,  3002.31640797,  3144.70133352],
#        [-1537.54665049,  -583.61827838,  -359.37779188, ...,
#          3541.18874435,  3209.09550286,  3364.87017283],
#        [-1269.26862199,  -286.86621853,   114.60205672, ...,
#          3698.74901895,  3230.54287209,  3403.76049487],
#        ...,
#        [ 5067.31429116,  5458.36656903,  7445.28966024, ...,
#          9165.25252246,  9560.92133611,  8828.60950806],
#        [ 5294.80392844,  5493.18161572,  8219.18735848, ...,
#          9613.21685814,  9970.9457582 ,  9052.66358792],
#        [ 6693.01109113,  6834.83195339,  8673.93255633, ...,
#          9942.65009323, 10610.55479546,  9299.02930604]])

# %%
Prophet_forecast.samples
# Out:
# array([[3824.36225969, 4433.31159491, 4223.45768444, ..., 6828.96343827,
#         7144.53142239, 3144.70133352],
#        [2116.214453  , 1272.67502633, 4137.58498379, ..., 7817.37598489,
#         3892.05433964, 5883.89144133],
#        [1368.71393983, 3872.48444849, 7008.61376665, ..., 7255.58647853,
#         6719.45067119, 3403.76049487],
#        ...,
#        [3387.09285195, 3512.51457245, 5138.6737077 , ..., 6875.26750232,
#         5226.01276706, 6179.37450673],
#        [4442.00401948, 2824.24122447, 1262.84693569, ..., 8179.28040396,
#         3809.37065383, 7438.01607015],
#        [ 399.8252015 , 5009.67939292, -359.37779188, ..., 8933.31436947,
#         8363.04232266, 6980.78786454]])

# %%
# DeepAR+

# %%
from gluonts.dataset.common import ListDataset
training_data = ListDataset(
    [{"start": data.index[0], "target": data.metric_value[:"2019-12-19 22:00:00"]}],
    freq = "H"
)

# %%
from gluonts.model.deepar import DeepAREstimator
from gluonts.trainer import Trainer

estimator = DeepAREstimator(freq="H", prediction_length=predict_len, trainer=Trainer(epochs=50))
predictor = estimator.train(training_data=training_data)
# Out:
# INFO:root:Using CPU
# INFO:root:Using CPU
# INFO:root:Start model training
# INFO:root:Epoch[0] Learning rate is 0.001
#   0%|          | 0/50 [00:00<?, ?it/s]INFO:root:Number of parameters in DeepARTrainingNetwork: 27644
# 100%|██████████| 50/50 [00:19<00:00,  2.55it/s, avg_epoch_loss=8.98]
# INFO:root:Epoch[0] Elapsed time 19.573 seconds
# INFO:root:Epoch[0] Evaluation metric 'epoch_loss'=8.976771
# INFO:root:Epoch[1] Learning rate is 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.50it/s, avg_epoch_loss=8.7]
# INFO:root:Epoch[1] Elapsed time 14.276 seconds
# INFO:root:Epoch[1] Evaluation metric 'epoch_loss'=8.703679
# INFO:root:Epoch[2] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.68it/s, avg_epoch_loss=8.59]
# INFO:root:Epoch[2] Elapsed time 13.603 seconds
# INFO:root:Epoch[2] Evaluation metric 'epoch_loss'=8.588931
# INFO:root:Epoch[3] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.67it/s, avg_epoch_loss=8.49]
# INFO:root:Epoch[3] Elapsed time 13.630 seconds
# INFO:root:Epoch[3] Evaluation metric 'epoch_loss'=8.488776
# INFO:root:Epoch[4] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.67it/s, avg_epoch_loss=8.38]
# INFO:root:Epoch[4] Elapsed time 13.632 seconds
# INFO:root:Epoch[4] Evaluation metric 'epoch_loss'=8.375889
# INFO:root:Epoch[5] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.66it/s, avg_epoch_loss=8.26]
# INFO:root:Epoch[5] Elapsed time 13.672 seconds
# INFO:root:Epoch[5] Evaluation metric 'epoch_loss'=8.259501
# INFO:root:Epoch[6] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.66it/s, avg_epoch_loss=8.15]
# INFO:root:Epoch[6] Elapsed time 13.646 seconds
# INFO:root:Epoch[6] Evaluation metric 'epoch_loss'=8.145566
# INFO:root:Epoch[7] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.66it/s, avg_epoch_loss=8.06]
# INFO:root:Epoch[7] Elapsed time 13.683 seconds
# INFO:root:Epoch[7] Evaluation metric 'epoch_loss'=8.061243
# INFO:root:Epoch[8] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.65it/s, avg_epoch_loss=8]
# INFO:root:Epoch[8] Elapsed time 13.717 seconds
# INFO:root:Epoch[8] Evaluation metric 'epoch_loss'=7.995250
# INFO:root:Epoch[9] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.65it/s, avg_epoch_loss=7.92]
# INFO:root:Epoch[9] Elapsed time 13.717 seconds
# INFO:root:Epoch[9] Evaluation metric 'epoch_loss'=7.918411
# INFO:root:Epoch[10] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.63it/s, avg_epoch_loss=7.87]
# INFO:root:Epoch[10] Elapsed time 13.786 seconds
# INFO:root:Epoch[10] Evaluation metric 'epoch_loss'=7.867201
# INFO:root:Epoch[11] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.58it/s, avg_epoch_loss=7.8]
# INFO:root:Epoch[11] Elapsed time 13.961 seconds
# INFO:root:Epoch[11] Evaluation metric 'epoch_loss'=7.800377
# INFO:root:Epoch[12] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3
Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.61it/s, avg_epoch_loss=6.97]
# INFO:root:Epoch[43] Elapsed time 13.836 seconds
# INFO:root:Epoch[43] Evaluation metric 'epoch_loss'=6.965756
# INFO:root:Epoch[44] Learning rate is 0.001
# 100%|██████████| 50/50 [00:13<00:00,  3.61it/s, avg_epoch_loss=6.95]
# INFO:root:Epoch[44] Elapsed time 13.842 seconds
# INFO:root:Epoch[44] Evaluation metric 'epoch_loss'=6.948057
# INFO:root:Epoch[45] Learning rate is 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.54it/s, avg_epoch_loss=6.92]
# INFO:root:Epoch[45] Elapsed time 14.136 seconds
# INFO:root:Epoch[45] Evaluation metric 'epoch_loss'=6.921366
# INFO:root:Epoch[46] Learning rate is 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.51it/s, avg_epoch_loss=6.92]
# INFO:root:Epoch[46] Elapsed time 14.247 seconds
# INFO:root:Epoch[46] Evaluation metric 'epoch_loss'=6.918532
# INFO:root:Epoch[47] Learning rate is 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.53it/s, avg_epoch_loss=6.89]
# INFO:root:Epoch[47] Elapsed time 14.159 seconds
# INFO:root:Epoch[47] Evaluation metric 'epoch_loss'=6.893840
# INFO:root:Epoch[48] Learning rate is 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.55it/s, avg_epoch_loss=6.89]
# INFO:root:Epoch[48] Elapsed time 14.106 seconds
# INFO:root:Epoch[48] Evaluation metric 'epoch_loss'=6.890917
# INFO:root:Epoch[49] Learning rate is 0.001
# 100%|██████████| 50/50 [00:14<00:00,  3.53it/s, avg_epoch_loss=6.85]
# INFO:root:Epoch[49] Elapsed time 14.171 seconds
# INFO:root:Epoch[49] Evaluation metric 'epoch_loss'=6.853335
# INFO:root:Loading parameters from best epoch (49)
# INFO:root:Final loss: 6.853335266113281 (occurred at epoch 49)
# INFO:root:End model training

# %%
estimator.dropout_rate
# Out:
# 0.1

# %%
train_len
# Out:
# 462

# %%
from pathlib import Path
predictor.serialize(Path("/tmp/"))

# %%
from gluonts.model.predictor import Predictor
from pathlib import Path
predictor_deserialized = Predictor.deserialize(Path("/tmp/"))
# Out:
# INFO:root:Using CPU

# %%
from gluonts.dataset.util import to_pandas

for test_entry, forecast in zip(training_data, predictor_deserialized.predict(training_data)):
#     to_pandas(test_entry)[:].plot(linewidth=2)
#     idx = pd.date_range(start='2019-12-19 23:00:00', periods=predict_len, freq='H')
#     Forecasting = pd.Series(forecast.median,index=idx)
    ax = train_data.plot()
    test_data.plot(ax=ax)
    forecast.plot(color='g', prediction_intervals=[0.0])
    DeepAR_forecast = forecast
#     Forecasting.plot(color='r', ls='--')
plt.grid(which='both')

# %%
# Root Mean Square Error (RMSE)
rmse_DeepAR = np.sqrt(mean_squared_error(test_data.metric_value, DeepAR_forecast.median[:test_len]))
rmse_DeepAR = round(rmse_DeepAR, 3)
rmse_DeepAR
# Out:
# 2437.875

# %%
# Mean Absolute Percentage Error
abs_error = np.abs(test_data['metric_value'] - DeepAR_forecast.median[:test_len])
actual = test_data['metric_value']
mape_DeepAR = np.round(np.mean(abs_error/actual),4)
mape_DeepAR
# Out:
# 0.3389

# %%
#demo lost function
def f(a,b):
    return a**2 + b**2

fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
# plt.hold(True)
a = np.arange(-2, 2, 0.25)
b = np.arange(-2, 2, 0.25)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
                       linewidth=0, antialiased=False,cmap='rainbow')
ax.set_zlim(-0.01, 8.01)
# Out:
# (-0.01, 8.01)

# %%
def gradient_descent(theta0, iters, alpha):
    history = [theta0] # to store all thetas
    theta = theta0     # initial values for thetas
    # main loop by iterations:
    for i in range(iters):
        # gradient is [2x, 2y]:
        gradient = [2.0*x for x in theta] 
        # update parameters:
        theta = [a - alpha*b for a,b in zip(theta, gradient)]
        history.append(theta)
    return history

history = gradient_descent(theta0 = [-1.8, 1.6], iters = 30, alpha = 0.03)

fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
# plt.hold(True)
a = np.arange(-2, 2, 0.25)
b = np.arange(-2, 2, 0.25)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
                       linewidth=0, antialiased=False)
ax.set_zlim(-0.01, 8.01)

a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c = f(a,b)
ax.scatter(a, b, c, color="r"); 

plt.show()

# %%
# test with data_transfer

# %%
from gluonts.dataset.common import ListDataset
training_data2 = ListDataset(
    [{"start": data2.index[0], "target": data2.metric_value[:"2019-12-19 22:00:00"]}],
    freq = "H"
)

# %%
train_data2 = data2['2019-11-30 17:00:00':'2019-12-19 22:00:00']
test_data2 = data2['2019-12-19 23:00:00':'2019-12-26 09:00:00']
train_len = len(train_data2)
test_len = len(test_data2)

# %%
from gluonts.dataset.util import to_pandas

for test_entry, forecast in zip(training_data2, predictor_deserialized.predict(training_data2)):
#     to_pandas(test_entry)[:].plot(linewidth=2)
#     idx = pd.date_range(start='2019-12-19 23:00:00', periods=predict_len, freq='H')
#     Forecasting = pd.Series(forecast.median,index=idx)
    ax = train_data2.plot()
    test_data2.plot(ax=ax)
    forecast.plot(color='g', prediction_intervals=[0.0])
    DeepAR_forecast2 = forecast
#     Forecasting.plot(color='r', ls='--')
plt.grid(which='both')

# %%
# Root Mean Square Error (RMSE)
rmse = np.sqrt(mean_squared_error(test_data.metric_value, DeepAR_forecast2.median[:test_len]))
rmse = round(rmse, 3)
rmse
# Out:
# 19256.807

# %%
# Mean Absolute Percentage Error
abs_error = np.abs(test_data['metric_value'] - DeepAR_forecast2.median[:test_len])
actual = test_data['metric_value']
mape = np.round(np.mean(abs_error/actual),4)
mape
# Out:
# 3.7517

# %%
idx = ['ARIMA', 'ETS', 'NPTS', 'Prophet', 'DeepAR']

# %%
data = [[rmse_ARIMA,mape_ARIMA],[rmse_ETS,mape_ETS],[rmse_NPTS,mape_NPTS],[rmse_Prophet,mape_Prophet],[rmse_DeepAR,mape_DeepAR]]
df = pd.DataFrame(data,columns=['RMSE','MAPE'], index=idx)

# %%
df
# Out:
#              RMSE    MAPE
# ARIMA    2370.960  0.4020
# ETS      2042.375  0.3634
# NPTS     2140.109  0.2719
# Prophet  1970.707  0.2823
# DeepAR   2437.875  0.3389
